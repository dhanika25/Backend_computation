# %%
import sqlite3
import pandas as pd
from Backtesting import Backtest as bt, data_retriever_util as dr
import plotly.graph_objects as go
import plotly.io as pio
from plotly.subplots import make_subplots
from Backtesting import utils as btutil
from Backtesting import Strategies as st

# Connect to the source SQLite database
source_db_path = "C:\\Users\\Dhanika Dewan\\Documents\\GitHub\\StockBuddyGenAI\\src\\Data\\NSE_Yahoo_9_FEB_24.sqlite"
source_conn = sqlite3.connect(source_db_path)

# Read the data into a pandas DataFrame
query = "SELECT * FROM NSE WHERE ticker = 'TATAMOTORS.NS'"
df = pd.read_sql(query, source_conn, parse_dates=['Date'])

# Close the connection to the source database
source_conn.close()
    
result= st.implement_parabolic_sar(df, toPlot=True)

print({
        'Win Rate [%]': result['Win Rate [%]'],
        'Net Profit/Loss [$]': result['Net Profit/Loss [$]'],
        'Total Trades': result['Total Trades'],
        'Winning Trades': result['Winning Trades']
    })

# Check if the result contains the plotlyJson key
if "plotlyJson" in result:
    # Convert JSON back to a Plotly figure
    fig = pio.from_json(result["plotlyJson"])
    # Display the figure
    fig.show()
else:
    print("Plotly JSON object not found in the result.")
# Out:
# False
# 8442
# Start                     1991-01-02 00:00:00
# End                       2024-05-31 00:00:00
# Duration                  12203 days 00:00:00
# Exposure Time [%]                   99.964463
# Equity Final [$]                  5436.057623
# Equity Peak [$]                 104234.435701
# Return [%]                         -45.639424
# Buy & Hold Return [%]             4129.598939
# Return (Ann.) [%]                   -1.803043
# Volatility (Ann.) [%]               44.483918
# Sharpe Ratio                              0.0
# Sortino Ratio                             0.0
# Calmar Ratio                              0.0
# Max. Drawdown [%]                  -95.612047
# Avg. Drawdown [%]                  -13.991754
# Max. Drawdown Duration     7536 days 00:00:00
# Avg. Drawdown Duration      220 days 00:00:00
# # Trades                                  742
# Win Rate [%]                        39.487871
# Best Trade [%]                      87.999994
# Worst Trade [%]                    -30.436465
# Avg. Trade [%]                      -0.091409
# Max. Trade Duration          90 days 00:00:00
# Avg. Trade Duration          17 days 00:00:00
# Profit Factor                        1.115569
# Expectancy [%]                       0.394556
# SQN                                 -0.050762
# _strategy                            backtest
# _equity_curve                             ...
# _trades                        Size  Entry...
# dtype: object
# {'Win Rate [%]': 39.487870619946094, 'Net Profit/Loss [$]': -4563.942377471978, 'Total Trades': 742, 'Winning Trades': 293.0}
